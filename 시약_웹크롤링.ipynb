# %% [markdown]
# <a href="https://colab.research.google.com/github/hongtaemin/-/blob/main/%EC%8B%9C%EC%95%BD_%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install playwright pandas openpyxl
# !playwright install --with-deps chromium

import re
import asyncio
import pandas as pd
from datetime import datetime
from urllib.parse import urlencode
from playwright.async_api import async_playwright, TimeoutError as PWTimeout

HOME = "https://www.dslab.co.kr"
SEARCH_URL = "https://www.dslab.co.kr/shop/search.php"

def log(msg: str):
    print(f"[{datetime.now().strftime('%H:%M:%S')}] {msg}", flush=True)

def parse_price(text: str):
    if not text:
        return None
    nums = re.sub(r"[^\d]", "", text)
    return int(nums) if nums else None

async def js_set_value(page, css: str, value: str):
    # ✅ evaluate에는 인자를 1개만 넘길 수 있어서 dict로 묶어 전달
    return await page.evaluate(
        """(args) => {
            const el = document.querySelector(args.sel);
            if (!el) return false;
            el.value = args.val;
            el.dispatchEvent(new Event('input', {bubbles:true}));
            el.dispatchEvent(new Event('change', {bubbles:true}));
            return true;
        }""",
        {"sel": css, "val": value}
    )

async def js_click(page, css: str, label: str):
    try:
        ok = await page.evaluate(
            """(sel) => {
                const el = document.querySelector(sel);
                if (!el) return false;
                try { el.scrollIntoView({block:'center', inline:'center'}); } catch(e) {}
                el.click();
                return true;
            }""",
            css
        )
        if ok:
            log(f"  ✔ 클릭(JS): {label} ({css})")
        else:
            log(f"  ✖ 클릭(JS) 실패(요소없음): {label} ({css})")
        return ok
    except Exception as e:
        log(f"  ✖ 클릭(JS) 예외: {label} / {type(e).__name__}: {e}")
        return False

async def goto_search_direct(page, keyword: str, page_no: int = 1):
    params = {"q": keyword, "page": page_no, "ckattempt": 1}
    url = f"{SEARCH_URL}?{urlencode(params)}"
    log(f"  ↪ 백업: 검색 URL 직접 이동: {url}")
    await page.goto(url, wait_until="domcontentloaded")

async def ensure_on_search_page(page, keyword: str):
    """
    홈에서 검색어 입력 + 돋보기 클릭 후 search.php로 진입을 보장.
    실패하면 search.php?q=... 로 직접 이동(백업)
    """
    await page.goto(HOME, wait_until="domcontentloaded")
    await page.wait_for_selector("input#sch_str", timeout=20000)

    # 입력 (fill + JS value 세팅)
    await page.locator("input#sch_str").fill(keyword)
    await js_set_value(page, "input#sch_str", keyword)
    log(f"  ✔ 검색어 입력 완료: '{keyword}'")

    # 돋보기 클릭(JS)
    await js_click(page, "button#sch_submit", "돋보기")

    # URL 이동 감지 대기 → 실패 시 직접 이동
    try:
        await page.wait_for_url("**/shop/search.php**", timeout=12000)
        log(f"  ✔ search.php 이동 확인 / URL: {page.url}")
    except PWTimeout:
        log(f"  ⚠ URL 이동 미감지 / 현재 URL: {page.url}")
        await goto_search_direct(page, keyword, page_no=1)

    # 결과 영역 대기(#sct가 없어도 ul.item-list만 있으면 진행)
    try:
        await page.wait_for_selector("#sct, ul.item-list", timeout=15000)
        return True
    except PWTimeout:
        return False

async def get_page_items_count(page):
    return await page.locator("ul.item-list > li").count()

async def extract_price_from_nth_item(page, idx_in_page: int):
    """
    idx_in_page: 1부터 시작(nth-child)
    CSS → XPath(상대) → Abs XPath(최후) 순으로 가격 strong을 찾음
    """
    # 1) CSS
    css_price = f"ul.item-list > li:nth-child({idx_in_page}) .con-price .price-price strong"
    if await page.locator(css_price).count() > 0:
        txt = (await page.locator(css_price).first.inner_text(timeout=5000)).strip()
        price = parse_price(txt)
        if price is not None:
            return price, f"CSS / 원문:{txt}"

    # 2) XPath(상대)
    xp_price = f"//ul[contains(@class,'item-list')]/li[{idx_in_page}]//div[contains(@class,'con-price')]//strong"
    xp_sel = f"xpath={xp_price}"
    if await page.locator(xp_sel).count() > 0:
        txt = (await page.locator(xp_sel).first.inner_text(timeout=5000)).strip()
        price = parse_price(txt)
        if price is not None:
            return price, f"XPATH / 원문:{txt}"

    # 3) Abs XPath(최후)
    abs_xp = f"/html/body//ul[contains(@class,'item-list')]/li[{idx_in_page}]/a//div[contains(@class,'con-price')]//strong"
    abs_sel = f"xpath={abs_xp}"
    if await page.locator(abs_sel).count() > 0:
        txt = (await page.locator(abs_sel).first.inner_text(timeout=5000)).strip()
        price = parse_price(txt)
        if price is not None:
            return price, f"ABS_XPATH / 원문:{txt}"

    return None, "가격 요소를 찾지 못함(CSS/XPath/AbsXPath 실패)"

async def fetch_nth_price(page, keyword, n, excel_row):
    keyword = "" if keyword is None else str(keyword).strip()
    if len(keyword) < 2:
        return None, "FAIL:검색어 2글자 미만"

    try:
        n = int(n)
    except:
        return None, f"FAIL:순번 정수 변환 실패({n})"
    if n < 1:
        return None, f"FAIL:순번 1 미만({n})"

    log(f"{excel_row}행 ▶ 검색 시작: '{keyword}' / 전체 {n}번째")

    ok = await ensure_on_search_page(page, keyword)
    if not ok:
        return None, "FAIL:검색 페이지 진입 실패(#sct/ul.item-list 미검출)"

    # 1페이지 결과 로딩 대기
    try:
        await page.wait_for_selector("ul.item-list > li", timeout=20000)
    except PWTimeout:
        if await get_page_items_count(page) == 0:
            return None, "FAIL:검색 결과 0개"
        return None, "FAIL:검색결과 로딩 실패"

    page_size = await get_page_items_count(page)
    log(f"  ▶ 1페이지 아이템 수(page_size)={page_size}")
    if page_size == 0:
        return None, "FAIL:검색 결과 0개"

    # 전체 n번째 → 목표 페이지/인덱스 계산
    target_page = (n - 1) // page_size + 1
    idx_in_page = (n - 1) % page_size + 1
    log(f"  ▶ 목표: page={target_page}, page내순번={idx_in_page}")

    # 목표 페이지로 직접 이동(가장 안정적)
    if target_page != 1:
        await goto_search_direct(page, keyword, page_no=target_page)
        try:
            await page.wait_for_selector("ul.item-list > li", timeout=20000)
        except PWTimeout:
            return None, "FAIL:목표 페이지 로딩 실패"

    cnt = await get_page_items_count(page)
    log(f"  ▶ 목표 페이지 아이템 수={cnt}")
    if idx_in_page > cnt:
        return None, f"FAIL:{n}번째 없음(목표 페이지 {cnt}개)"

    price, detail = await extract_price_from_nth_item(page, idx_in_page)
    if price is None:
        return None, f"FAIL:{detail}"

    return price, f"OK:{price} / {detail}"

async def go_home(page):
    # 요구사항: 로고 클릭으로 홈 복귀 시도 → 실패하면 HOME 직접 이동
    try:
        a_kr = page.locator("a:has(span.logo-kr)")
        if await a_kr.count() > 0:
            try:
                await a_kr.first.click(force=True, timeout=5000)
                await page.wait_for_load_state("domcontentloaded")
                await page.wait_for_selector("input#sch_str", timeout=20000)
                return
            except:
                pass
    except:
        pass

    for sel in ["span.logo-kr", "span.logo-en"]:
        try:
            if await page.locator(sel).count() > 0:
                await js_click(page, sel, f"로고({sel})")
                await page.wait_for_load_state("domcontentloaded")
                await page.wait_for_selector("input#sch_str", timeout=20000)
                return
        except:
            pass

    await page.goto(HOME, wait_until="domcontentloaded")
    await page.wait_for_selector("input#sch_str", timeout=20000)

async def main_async(input_xlsx="input.xlsx", output_xlsx="output.xlsx"):
    log(f"엑셀 로드: {input_xlsx}")
    df = pd.read_excel(input_xlsx)
    log(f"엑셀 로드 완료: {len(df)}행 / {len(df.columns)}열")

    # 3열이 없으면 생성
    while df.shape[1] < 3:
        df[f"col{df.shape[1]+1}"] = None

    prices = []

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page(viewport={"width": 1280, "height": 900})

        # 검색어 검증 alert가 뜨면 자동 닫기
        page.on("dialog", lambda d: asyncio.create_task(d.accept()))

        for i, row in df.iterrows():
            excel_row = i + 1
            keyword = row.iloc[0]
            nth = row.iloc[1]

            log("=" * 80)
            log(f"{excel_row}행 시작 ▶ 검색명='{keyword}' / 순번='{nth}'")

            try:
                price, status = await fetch_nth_price(page, keyword, nth, excel_row)
            except Exception as e:
                price, status = None, f"EXCEPTION:{type(e).__name__}:{e}"

            prices.append(price)
            log(f"{excel_row}행 결과 ▶ 가격={price} / 상태={status}")

            await go_home(page)
            await asyncio.sleep(0.15)

        await browser.close()

    df.iloc[:, 2] = prices
    df.to_excel(output_xlsx, index=False)
    log(f"완료 ▶ {output_xlsx} 저장")

# Colab 실행
await main_async("input.xlsx", "output.xlsx")
# Out:
# Installing dependencies...
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.047-0ubuntu0.22.04.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.16).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.6).
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 48 not upgraded.
# [04:50:31] 엑셀 로드: input.xlsx
# [04:50:31] 엑셀 로드 완료: 139행 / 2열
# [04:50:32] ================================================================================
# [04:50:32] 1행 시작 ▶ 검색명='Formic Acid  85  EP  개미산' / 순번='1'
# [04:50:32] 1행 ▶ 검색 시작: 'Formic Acid  85  EP  개미산' / 전체 1번째
# [04:50:35]   ✔ 검색어 입력 완료: 'Formic Acid  85  EP  개미산'
# [04:50:35]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:36]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Formic+Acid++85++EP++%EA%B0%9C%EB%AF%B8%EC%82%B0
# [04:50:36]   ▶ 1페이지 아이템 수(page_size)=5
# [04:50:36]   ▶ 목표: page=1, page내순번=1
# [04:50:36]   ▶ 목표 페이지 아이템 수=5
# [04:50:36] 1행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# ERROR:asyncio:Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# [04:50:37] ================================================================================
# [04:50:37] 2행 시작 ▶ 검색명='Sodium Silicate Solution  CP  규산나트륨용액 물유리' / 순번='1'
# [04:50:37] 2행 ▶ 검색 시작: 'Sodium Silicate Solution  CP  규산나트륨용액 물유리' / 전체 1번째
# [04:50:38]   ✔ 검색어 입력 완료: 'Sodium Silicate Solution  CP  규산나트륨용액 물유리'
# [04:50:38]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:39]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Silicate+Solution++CP++%EA%B7%9C%EC%82%B0%EB%82%98%ED%8A%B8%EB%A5%A8%EC%9A%A9%EC%95%A1+%EB%AC%BC%EC%9C%A0%EB%A6%AC
# [04:50:40]   ▶ 1페이지 아이템 수(page_size)=3
# [04:50:40]   ▶ 목표: page=1, page내순번=1
# [04:50:40]   ▶ 목표 페이지 아이템 수=3
# [04:50:40] 2행 결과 ▶ 가격=5830 / 상태=OK:5830 / CSS / 원문:5,830
# [04:50:40] ================================================================================
# [04:50:40] 3행 시작 ▶ 검색명='Dextrose Anhydrous  98.0  EP  덱스트로즈포도당' / 순번='1'
# [04:50:40] 3행 ▶ 검색 시작: 'Dextrose Anhydrous  98.0  EP  덱스트로즈포도당' / 전체 1번째
# [04:50:41]   ✔ 검색어 입력 완료: 'Dextrose Anhydrous  98.0  EP  덱스트로즈포도당'
# [04:50:41]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:42]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Dextrose+Anhydrous++98.0++EP++%EB%8D%B1%EC%8A%A4%ED%8A%B8%EB%A1%9C%EC%A6%88%ED%8F%AC%EB%8F%84%EB%8B%B9
# [04:50:42]   ▶ 1페이지 아이템 수(page_size)=2
# [04:50:42]   ▶ 목표: page=1, page내순번=1
# [04:50:42]   ▶ 목표 페이지 아이템 수=2
# [04:50:43] 3행 결과 ▶ 가격=6930 / 상태=OK:6930 / CSS / 원문:6,930
# [04:50:44] ================================================================================
# [04:50:44] 4행 시작 ▶ 검색명='NN-Dimethylformamide  99.8  GR  NN디메틸포름아미드' / 순번='1'
# [04:50:44] 4행 ▶ 검색 시작: 'NN-Dimethylformamide  99.8  GR  NN디메틸포름아미드' / 전체 1번째
# [04:50:45]   ✔ 검색어 입력 완료: 'NN-Dimethylformamide  99.8  GR  NN디메틸포름아미드'
# [04:50:45]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:46]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=NN-Dimethylformamide++99.8++GR++NN%EB%94%94%EB%A9%94%ED%8B%B8%ED%8F%AC%EB%A6%84%EC%95%84%EB%AF%B8%EB%93%9C
# [04:50:46]   ▶ 1페이지 아이템 수(page_size)=1
# [04:50:46]   ▶ 목표: page=1, page내순번=1
# [04:50:46]   ▶ 목표 페이지 아이템 수=1
# [04:50:46] 4행 결과 ▶ 가격=8690 / 상태=OK:8690 / CSS / 원문:8,690
# [04:50:47] ================================================================================
# [04:50:47] 5행 시작 ▶ 검색명='Dichloromethane Methylene chloride MC  99.5  EP  디클로로메탄염화메틸렌' / 순번='1'
# [04:50:47] 5행 ▶ 검색 시작: 'Dichloromethane Methylene chloride MC  99.5  EP  디클로로메탄염화메틸렌' / 전체 1번째
# [04:50:48]   ✔ 검색어 입력 완료: 'Dichloromethane Methylene chloride MC  99.5  EP  디클로로메탄염화메틸렌'
# [04:50:48]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:50]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Dichloromethane+Methylene+chloride+MC++99.5++EP++%EB%94%94%ED%81%B4%EB%A1%9C%EB%A1%9C%EB%A9%94%ED%83%84%EC%97%BC%ED%99%94%EB%A9%94%ED%8B%B8%EB%A0%8C
# [04:50:50]   ▶ 1페이지 아이템 수(page_size)=27
# [04:50:50]   ▶ 목표: page=1, page내순번=1
# [04:50:50]   ▶ 목표 페이지 아이템 수=27
# [04:50:50] 5행 결과 ▶ 가격=81180 / 상태=OK:81180 / CSS / 원문:81,180
# [04:50:50] ================================================================================
# [04:50:50] 6행 시작 ▶ 검색명='Resorcinol  98  EP  레졸시놀' / 순번='1'
# [04:50:50] 6행 ▶ 검색 시작: 'Resorcinol  98  EP  레졸시놀' / 전체 1번째
# [04:50:51]   ✔ 검색어 입력 완료: 'Resorcinol  98  EP  레졸시놀'
# [04:50:51]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:52]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Resorcinol++98++EP++%EB%A0%88%EC%A1%B8%EC%8B%9C%EB%86%80
# [04:50:53]   ▶ 1페이지 아이템 수(page_size)=1
# [04:50:53]   ▶ 목표: page=1, page내순번=1
# [04:50:53]   ▶ 목표 페이지 아이템 수=1
# [04:50:53] 6행 결과 ▶ 가격=30250 / 상태=OK:30250 / CSS / 원문:30,250
# [04:50:54] ================================================================================
# [04:50:54] 7행 시작 ▶ 검색명='Acetic Anhydride  97  EP  무수아세트산' / 순번='1'
# [04:50:54] 7행 ▶ 검색 시작: 'Acetic Anhydride  97  EP  무수아세트산' / 전체 1번째
# [04:50:55]   ✔ 검색어 입력 완료: 'Acetic Anhydride  97  EP  무수아세트산'
# [04:50:55]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:50:56]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetic+Anhydride++97++EP++%EB%AC%B4%EC%88%98%EC%95%84%EC%84%B8%ED%8A%B8%EC%82%B0
# [04:50:56]   ▶ 1페이지 아이템 수(page_size)=2
# [04:50:56]   ▶ 목표: page=1, page내순번=1
# [04:50:56]   ▶ 목표 페이지 아이템 수=2
# [04:50:56] 7행 결과 ▶ 가격=14300 / 상태=OK:14300 / CSS / 원문:14,300
# [04:50:58] ================================================================================
# [04:50:58] 8행 시작 ▶ 검색명='Sodium borate anhydrous 99 붕사' / 순번='첫번째 품목 안에 규격별 가격 보고 해야함'
# [04:50:58] 8행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(첫번째 품목 안에 규격별 가격 보고 해야함)
# [04:50:59] ================================================================================
# [04:50:59] 9행 시작 ▶ 검색명='Boric Acid  99.5  EP  붕산' / 순번='1'
# [04:50:59] 9행 ▶ 검색 시작: 'Boric Acid  99.5  EP  붕산' / 전체 1번째
# [04:51:00]   ✔ 검색어 입력 완료: 'Boric Acid  99.5  EP  붕산'
# [04:51:00]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:02]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Boric+Acid++99.5++EP++%EB%B6%95%EC%82%B0
# [04:51:02]   ▶ 1페이지 아이템 수(page_size)=6
# [04:51:02]   ▶ 목표: page=1, page내순번=1
# [04:51:02]   ▶ 목표 페이지 아이템 수=6
# [04:51:02] 9행 결과 ▶ 가격=8690 / 상태=OK:8690 / CSS / 원문:8,690
# [04:51:03] ================================================================================
# [04:51:03] 10행 시작 ▶ 검색명='Magnesium Oxide Light  산화마그네슘 경질' / 순번='1'
# [04:51:03] 10행 ▶ 검색 시작: 'Magnesium Oxide Light  산화마그네슘 경질' / 전체 1번째
# [04:51:04]   ✔ 검색어 입력 완료: 'Magnesium Oxide Light  산화마그네슘 경질'
# [04:51:04]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:05]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Magnesium+Oxide+Light++%EC%82%B0%ED%99%94%EB%A7%88%EA%B7%B8%EB%84%A4%EC%8A%98+%EA%B2%BD%EC%A7%88
# [04:51:05]   ▶ 1페이지 아이템 수(page_size)=3
# [04:51:05]   ▶ 목표: page=1, page내순번=1
# [04:51:05]   ▶ 목표 페이지 아이템 수=3
# [04:51:05] 10행 결과 ▶ 가격=12100 / 상태=OK:12100 / CSS / 원문:12,100
# [04:51:06] ================================================================================
# [04:51:06] 11행 시작 ▶ 검색명='Aluminum Oxide 99 EP' / 순번='1'
# [04:51:06] 11행 ▶ 검색 시작: 'Aluminum Oxide 99 EP' / 전체 1번째
# [04:51:07]   ✔ 검색어 입력 완료: 'Aluminum Oxide 99 EP'
# [04:51:07]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:08]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Aluminum+Oxide+99+EP
# [04:51:08]   ▶ 1페이지 아이템 수(page_size)=1
# [04:51:08]   ▶ 목표: page=1, page내순번=1
# [04:51:08]   ▶ 목표 페이지 아이템 수=1
# [04:51:08] 11행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:51:09] ================================================================================
# [04:51:09] 12행 시작 ▶ 검색명='Petroleum Ether 90 EP' / 순번='2'
# [04:51:09] 12행 ▶ 검색 시작: 'Petroleum Ether 90 EP' / 전체 2번째
# [04:51:10]   ✔ 검색어 입력 완료: 'Petroleum Ether 90 EP'
# [04:51:10]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:11]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Petroleum+Ether+90+EP
# [04:51:11]   ▶ 1페이지 아이템 수(page_size)=4
# [04:51:11]   ▶ 목표: page=1, page내순번=2
# [04:51:11]   ▶ 목표 페이지 아이템 수=4
# [04:51:11] 12행 결과 ▶ 가격=8690 / 상태=OK:8690 / CSS / 원문:8,690
# [04:51:12] ================================================================================
# [04:51:12] 13행 시작 ▶ 검색명='Silicagel Blue' / 순번='1'
# [04:51:12] 13행 ▶ 검색 시작: 'Silicagel Blue' / 전체 1번째
# [04:51:13]   ✔ 검색어 입력 완료: 'Silicagel Blue'
# [04:51:13]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:14]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Silicagel+Blue
# [04:51:14]   ▶ 1페이지 아이템 수(page_size)=6
# [04:51:14]   ▶ 목표: page=1, page내순번=1
# [04:51:14]   ▶ 목표 페이지 아이템 수=6
# [04:51:14] 13행 결과 ▶ 가격=8910 / 상태=OK:8910 / CSS / 원문:8,910
# [04:51:15] ================================================================================
# [04:51:15] 14행 시작 ▶ 검색명='Silicon carbide' / 순번='견적문의_1'
# [04:51:15] 14행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(견적문의_1)
# [04:51:17] ================================================================================
# [04:51:17] 15행 시작 ▶ 검색명='아스코빈산 비타민 C' / 순번='6'
# [04:51:17] 15행 ▶ 검색 시작: '아스코빈산 비타민 C' / 전체 6번째
# [04:51:18]   ✔ 검색어 입력 완료: '아스코빈산 비타민 C'
# [04:51:18]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:19]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=%EC%95%84%EC%8A%A4%EC%BD%94%EB%B9%88%EC%82%B0+%EB%B9%84%ED%83%80%EB%AF%BC+C
# [04:51:19]   ▶ 1페이지 아이템 수(page_size)=6
# [04:51:19]   ▶ 목표: page=1, page내순번=6
# [04:51:19]   ▶ 목표 페이지 아이템 수=6
# [04:51:19] 15행 결과 ▶ 가격=30250 / 상태=OK:30250 / CSS / 원문:30,250
# [04:51:20] ================================================================================
# [04:51:20] 16행 시작 ▶ 검색명='Sodium Sulfite Anhydrous  95  EP  아황산나트륨' / 순번='2'
# [04:51:20] 16행 ▶ 검색 시작: 'Sodium Sulfite Anhydrous  95  EP  아황산나트륨' / 전체 2번째
# [04:51:20]   ✔ 검색어 입력 완료: 'Sodium Sulfite Anhydrous  95  EP  아황산나트륨'
# [04:51:21]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:22]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Sulfite+Anhydrous++95++EP++%EC%95%84%ED%99%A9%EC%82%B0%EB%82%98%ED%8A%B8%EB%A5%A8
# [04:51:22]   ▶ 1페이지 아이템 수(page_size)=3
# [04:51:22]   ▶ 목표: page=1, page내순번=2
# [04:51:22]   ▶ 목표 페이지 아이템 수=3
# [04:51:22] 16행 결과 ▶ 가격=5830 / 상태=OK:5830 / CSS / 원문:5,830
# [04:51:23] ================================================================================
# [04:51:23] 17행 시작 ▶ 검색명='Lactose monohydrate GR' / 순번='1'
# [04:51:23] 17행 ▶ 검색 시작: 'Lactose monohydrate GR' / 전체 1번째
# [04:51:24]   ✔ 검색어 입력 완료: 'Lactose monohydrate GR'
# [04:51:24]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:25]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Lactose+monohydrate+GR
# [04:51:25]   ▶ 1페이지 아이템 수(page_size)=2
# [04:51:25]   ▶ 목표: page=1, page내순번=1
# [04:51:25]   ▶ 목표 페이지 아이템 수=2
# [04:51:25] 17행 결과 ▶ 가격=13090 / 상태=OK:13090 / CSS / 원문:13,090
# [04:51:26] ================================================================================
# [04:51:26] 18행 시작 ▶ 검색명='Starch Soluble EP' / 순번='2'
# [04:51:26] 18행 ▶ 검색 시작: 'Starch Soluble EP' / 전체 2번째
# [04:51:27]   ✔ 검색어 입력 완료: 'Starch Soluble EP'
# [04:51:27]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:28]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Starch+Soluble+EP
# [04:51:28]   ▶ 1페이지 아이템 수(page_size)=2
# [04:51:28]   ▶ 목표: page=1, page내순번=2
# [04:51:28]   ▶ 목표 페이지 아이템 수=2
# [04:51:28] 18행 결과 ▶ 가격=18150 / 상태=OK:18150 / CSS / 원문:18,150
# [04:51:30] ================================================================================
# [04:51:30] 19행 시작 ▶ 검색명='Gelatin EP' / 순번='2'
# [04:51:30] 19행 ▶ 검색 시작: 'Gelatin EP' / 전체 2번째
# [04:51:31]   ✔ 검색어 입력 완료: 'Gelatin EP'
# [04:51:31]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:32]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Gelatin+EP
# [04:51:33]   ▶ 1페이지 아이템 수(page_size)=6
# [04:51:33]   ▶ 목표: page=1, page내순번=2
# [04:51:33]   ▶ 목표 페이지 아이템 수=6
# [04:51:33] 19행 결과 ▶ 가격=16500 / 상태=OK:16500 / CSS / 원문:16,500
# [04:51:34] ================================================================================
# [04:51:34] 20행 시작 ▶ 검색명='Calcium Carbonate 98 EP' / 순번='1'
# [04:51:34] 20행 ▶ 검색 시작: 'Calcium Carbonate 98 EP' / 전체 1번째
# [04:51:35]   ✔ 검색어 입력 완료: 'Calcium Carbonate 98 EP'
# [04:51:35]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:36]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Calcium+Carbonate+98+EP
# [04:51:36]   ▶ 1페이지 아이템 수(page_size)=6
# [04:51:36]   ▶ 목표: page=1, page내순번=1
# [04:51:36]   ▶ 목표 페이지 아이템 수=6
# [04:51:36] 20행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:51:37] ================================================================================
# [04:51:37] 21행 시작 ▶ 검색명='Triethanolamine TEA 99 EP' / 순번='1'
# [04:51:37] 21행 ▶ 검색 시작: 'Triethanolamine TEA 99 EP' / 전체 1번째
# [04:51:38]   ✔ 검색어 입력 완료: 'Triethanolamine TEA 99 EP'
# [04:51:38]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:39]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Triethanolamine+TEA+99+EP
# [04:51:39]   ▶ 1페이지 아이템 수(page_size)=2
# [04:51:39]   ▶ 목표: page=1, page내순번=1
# [04:51:39]   ▶ 목표 페이지 아이템 수=2
# [04:51:39] 21행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:51:40] ================================================================================
# [04:51:40] 22행 시작 ▶ 검색명='Sodium Thiosulfate Pentahydrate 98.5 EP' / 순번='2'
# [04:51:40] 22행 ▶ 검색 시작: 'Sodium Thiosulfate Pentahydrate 98.5 EP' / 전체 2번째
# [04:51:41]   ✔ 검색어 입력 완료: 'Sodium Thiosulfate Pentahydrate 98.5 EP'
# [04:51:41]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:42]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Thiosulfate+Pentahydrate+98.5+EP
# [04:51:42]   ▶ 1페이지 아이템 수(page_size)=8
# [04:51:42]   ▶ 목표: page=1, page내순번=2
# [04:51:42]   ▶ 목표 페이지 아이템 수=8
# [04:51:42] 22행 결과 ▶ 가격=5830 / 상태=OK:5830 / CSS / 원문:5,830
# [04:51:43] ================================================================================
# [04:51:43] 23행 시작 ▶ 검색명='Peptone' / 순번='2'
# [04:51:43] 23행 ▶ 검색 시작: 'Peptone' / 전체 2번째
# [04:51:44]   ✔ 검색어 입력 완료: 'Peptone'
# [04:51:44]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:45]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Peptone
# [04:51:46]   ▶ 1페이지 아이템 수(page_size)=30
# [04:51:46]   ▶ 목표: page=1, page내순번=2
# [04:51:46]   ▶ 목표 페이지 아이템 수=30
# [04:51:46] 23행 결과 ▶ 가격=64900 / 상태=OK:64900 / CSS / 원문:64,900
# [04:51:47] ================================================================================
# [04:51:47] 24행 시작 ▶ 검색명='Polyvinyl Alcohol PVA 500 CP' / 순번='1'
# [04:51:47] 24행 ▶ 검색 시작: 'Polyvinyl Alcohol PVA 500 CP' / 전체 1번째
# [04:51:48]   ✔ 검색어 입력 완료: 'Polyvinyl Alcohol PVA 500 CP'
# [04:51:48]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:49]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Polyvinyl+Alcohol+PVA+500+CP
# [04:51:49]   ▶ 1페이지 아이템 수(page_size)=4
# [04:51:49]   ▶ 목표: page=1, page내순번=1
# [04:51:49]   ▶ 목표 페이지 아이템 수=4
# [04:51:49] 24행 결과 ▶ 가격=13750 / 상태=OK:13750 / CSS / 원문:13,750
# [04:51:50] ================================================================================
# [04:51:50] 25행 시작 ▶ 검색명='Magnesium Sulfate Anhydrous 99 EP' / 순번='첫번째 품목 안에 규격별 가격 보고 해야함'
# [04:51:50] 25행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(첫번째 품목 안에 규격별 가격 보고 해야함)
# [04:51:51] ================================================================================
# [04:51:51] 26행 시작 ▶ 검색명='Magnesium Sulfate Heptahydrate 99 EP' / 순번='1'
# [04:51:51] 26행 ▶ 검색 시작: 'Magnesium Sulfate Heptahydrate 99 EP' / 전체 1번째
# [04:51:52]   ✔ 검색어 입력 완료: 'Magnesium Sulfate Heptahydrate 99 EP'
# [04:51:52]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:53]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Magnesium+Sulfate+Heptahydrate+99+EP
# [04:51:53]   ▶ 1페이지 아이템 수(page_size)=11
# [04:51:53]   ▶ 목표: page=1, page내순번=1
# [04:51:53]   ▶ 목표 페이지 아이템 수=11
# [04:51:53] 26행 결과 ▶ 가격=5830 / 상태=OK:5830 / CSS / 원문:5,830
# [04:51:54] ================================================================================
# [04:51:54] 27행 시작 ▶ 검색명='Ammonium Sulfate  99  EP  황산암모늄' / 순번='2'
# [04:51:54] 27행 ▶ 검색 시작: 'Ammonium Sulfate  99  EP  황산암모늄' / 전체 2번째
# [04:51:55]   ✔ 검색어 입력 완료: 'Ammonium Sulfate  99  EP  황산암모늄'
# [04:51:55]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:56]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Ammonium+Sulfate++99++EP++%ED%99%A9%EC%82%B0%EC%95%94%EB%AA%A8%EB%8A%84
# [04:51:57]   ▶ 1페이지 아이템 수(page_size)=6
# [04:51:57]   ▶ 목표: page=1, page내순번=2
# [04:51:57]   ▶ 목표 페이지 아이템 수=6
# [04:51:57] 27행 결과 ▶ 가격=5280 / 상태=OK:5280 / CSS / 원문:5,280
# [04:51:57] ================================================================================
# [04:51:57] 28행 시작 ▶ 검색명='0.01mol L-Sodium Thiosulfate Solution' / 순번='1'
# [04:51:57] 28행 ▶ 검색 시작: '0.01mol L-Sodium Thiosulfate Solution' / 전체 1번째
# [04:51:58]   ✔ 검색어 입력 완료: '0.01mol L-Sodium Thiosulfate Solution'
# [04:51:58]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:51:59]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.01mol+L-Sodium+Thiosulfate+Solution
# [04:51:59]   ▶ 1페이지 아이템 수(page_size)=1
# [04:51:59]   ▶ 목표: page=1, page내순번=1
# [04:51:59]   ▶ 목표 페이지 아이템 수=1
# [04:51:59] 28행 결과 ▶ 가격=6930 / 상태=OK:6930 / CSS / 원문:6,930
# [04:52:00] ================================================================================
# [04:52:00] 29행 시작 ▶ 검색명='0.1mol L-Hydrochloric Acid' / 순번='1'
# [04:52:00] 29행 ▶ 검색 시작: '0.1mol L-Hydrochloric Acid' / 전체 1번째
# [04:52:01]   ✔ 검색어 입력 완료: '0.1mol L-Hydrochloric Acid'
# [04:52:01]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:03]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.1mol+L-Hydrochloric+Acid
# [04:52:03]   ▶ 1페이지 아이템 수(page_size)=3
# [04:52:03]   ▶ 목표: page=1, page내순번=1
# [04:52:03]   ▶ 목표 페이지 아이템 수=3
# [04:52:03] 29행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:52:05] ================================================================================
# [04:52:05] 30행 시작 ▶ 검색명='0.1mol L-Sodium Thiosulfate Solution' / 순번='1'
# [04:52:05] 30행 ▶ 검색 시작: '0.1mol L-Sodium Thiosulfate Solution' / 전체 1번째
# [04:52:05]   ✔ 검색어 입력 완료: '0.1mol L-Sodium Thiosulfate Solution'
# [04:52:05]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:07]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.1mol+L-Sodium+Thiosulfate+Solution
# [04:52:07]   ▶ 1페이지 아이템 수(page_size)=1
# [04:52:07]   ▶ 목표: page=1, page내순번=1
# [04:52:07]   ▶ 목표 페이지 아이템 수=1
# [04:52:07] 30행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:52:08] ================================================================================
# [04:52:08] 31행 시작 ▶ 검색명='Thiosulfate Standard Solution' / 순번='1'
# [04:52:08] 31행 ▶ 검색 시작: 'Thiosulfate Standard Solution' / 전체 1번째
# [04:52:08]   ✔ 검색어 입력 완료: 'Thiosulfate Standard Solution'
# [04:52:08]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:10]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Thiosulfate+Standard+Solution
# [04:52:10]   ▶ 1페이지 아이템 수(page_size)=5
# [04:52:10]   ▶ 목표: page=1, page내순번=1
# [04:52:10]   ▶ 목표 페이지 아이템 수=5
# [04:52:10] 31행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:52:11] ================================================================================
# [04:52:11] 32행 시작 ▶ 검색명='Phenolphthalein Solution' / 순번='3'
# [04:52:11] 32행 ▶ 검색 시작: 'Phenolphthalein Solution' / 전체 3번째
# [04:52:11]   ✔ 검색어 입력 완료: 'Phenolphthalein Solution'
# [04:52:11]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:13]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Phenolphthalein+Solution
# [04:52:13]   ▶ 1페이지 아이템 수(page_size)=6
# [04:52:13]   ▶ 목표: page=1, page내순번=3
# [04:52:13]   ▶ 목표 페이지 아이템 수=6
# [04:52:13] 32행 결과 ▶ 가격=9350 / 상태=OK:9350 / CSS / 원문:9,350
# [04:52:14] ================================================================================
# [04:52:14] 33행 시작 ▶ 검색명='1mol L-Sodium Hydroxide Solution' / 순번='1'
# [04:52:14] 33행 ▶ 검색 시작: '1mol L-Sodium Hydroxide Solution' / 전체 1번째
# [04:52:14]   ✔ 검색어 입력 완료: '1mol L-Sodium Hydroxide Solution'
# [04:52:14]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:16]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=1mol+L-Sodium+Hydroxide+Solution
# [04:52:16]   ▶ 1페이지 아이템 수(page_size)=4
# [04:52:16]   ▶ 목표: page=1, page내순번=1
# [04:52:16]   ▶ 목표 페이지 아이템 수=4
# [04:52:16] 33행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:52:17] ================================================================================
# [04:52:17] 34행 시작 ▶ 검색명='1mol L-Hydrochloric Acid' / 순번='1'
# [04:52:17] 34행 ▶ 검색 시작: '1mol L-Hydrochloric Acid' / 전체 1번째
# [04:52:18]   ✔ 검색어 입력 완료: '1mol L-Hydrochloric Acid'
# [04:52:18]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:19]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=1mol+L-Hydrochloric+Acid
# [04:52:19]   ▶ 1페이지 아이템 수(page_size)=5
# [04:52:19]   ▶ 목표: page=1, page내순번=1
# [04:52:19]   ▶ 목표 페이지 아이템 수=5
# [04:52:19] 34행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:52:20] ================================================================================
# [04:52:20] 35행 시작 ▶ 검색명='Hydrogen Peroxide 30 EP' / 순번='1'
# [04:52:20] 35행 ▶ 검색 시작: 'Hydrogen Peroxide 30 EP' / 전체 1번째
# [04:52:21]   ✔ 검색어 입력 완료: 'Hydrogen Peroxide 30 EP'
# [04:52:21]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:22]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Hydrogen+Peroxide+30+EP
# [04:52:23]   ▶ 1페이지 아이템 수(page_size)=9
# [04:52:23]   ▶ 목표: page=1, page내순번=1
# [04:52:23]   ▶ 목표 페이지 아이템 수=9
# [04:52:23] 35행 결과 ▶ 가격=10340 / 상태=OK:10340 / CSS / 원문:10,340
# [04:52:23] ================================================================================
# [04:52:23] 36행 시작 ▶ 검색명='Hydrogen Peroxide 28 EP' / 순번='2'
# [04:52:23] 36행 ▶ 검색 시작: 'Hydrogen Peroxide 28 EP' / 전체 2번째
# [04:52:24]   ✔ 검색어 입력 완료: 'Hydrogen Peroxide 28 EP'
# [04:52:24]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:25]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Hydrogen+Peroxide+28+EP
# [04:52:25]   ▶ 1페이지 아이템 수(page_size)=3
# [04:52:25]   ▶ 목표: page=1, page내순번=2
# [04:52:25]   ▶ 목표 페이지 아이템 수=3
# [04:52:25] 36행 결과 ▶ 가격=8250 / 상태=OK:8250 / CSS / 원문:8,250
# [04:52:26] ================================================================================
# [04:52:26] 37행 시작 ▶ 검색명='Hydrogen Peroxide 34.5 EP' / 순번='2'
# [04:52:26] 37행 ▶ 검색 시작: 'Hydrogen Peroxide 34.5 EP' / 전체 2번째
# [04:52:27]   ✔ 검색어 입력 완료: 'Hydrogen Peroxide 34.5 EP'
# [04:52:27]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:28]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Hydrogen+Peroxide+34.5+EP
# [04:52:28]   ▶ 1페이지 아이템 수(page_size)=3
# [04:52:28]   ▶ 목표: page=1, page내순번=2
# [04:52:28]   ▶ 목표 페이지 아이템 수=3
# [04:52:28] 37행 결과 ▶ 가격=9680 / 상태=OK:9680 / CSS / 원문:9,680
# [04:52:29] ================================================================================
# [04:52:29] 38행 시작 ▶ 검색명='Hydrogen Peroxide 30 35.5 GR' / 순번='1'
# [04:52:29] 38행 ▶ 검색 시작: 'Hydrogen Peroxide 30 35.5 GR' / 전체 1번째
# [04:52:30]   ✔ 검색어 입력 완료: 'Hydrogen Peroxide 30 35.5 GR'
# [04:52:30]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:31]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Hydrogen+Peroxide+30+35.5+GR
# [04:52:31]   ▶ 1페이지 아이템 수(page_size)=2
# [04:52:31]   ▶ 목표: page=1, page내순번=1
# [04:52:31]   ▶ 목표 페이지 아이템 수=2
# [04:52:31] 38행 결과 ▶ 가격=12100 / 상태=OK:12100 / CSS / 원문:12,100
# [04:52:32] ================================================================================
# [04:52:32] 39행 시작 ▶ 검색명='Perchloric Acid 70 72 GR' / 순번='1'
# [04:52:32] 39행 ▶ 검색 시작: 'Perchloric Acid 70 72 GR' / 전체 1번째
# [04:52:33]   ✔ 검색어 입력 완료: 'Perchloric Acid 70 72 GR'
# [04:52:33]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:35]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Perchloric+Acid+70+72+GR
# [04:52:35]   ▶ 1페이지 아이템 수(page_size)=1
# [04:52:35]   ▶ 목표: page=1, page내순번=1
# [04:52:35]   ▶ 목표 페이지 아이템 수=1
# [04:52:35] 39행 결과 ▶ 가격=37180 / 상태=OK:37180 / CSS / 원문:37,180
# [04:52:36] ================================================================================
# [04:52:36] 40행 시작 ▶ 검색명='Citric Acid Monohydrate  99.5  EP  구연산 1수화물' / 순번='4'
# [04:52:36] 40행 ▶ 검색 시작: 'Citric Acid Monohydrate  99.5  EP  구연산 1수화물' / 전체 4번째
# [04:52:36]   ✔ 검색어 입력 완료: 'Citric Acid Monohydrate  99.5  EP  구연산 1수화물'
# [04:52:36]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:38]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Citric+Acid+Monohydrate++99.5++EP++%EA%B5%AC%EC%97%B0%EC%82%B0+1%EC%88%98%ED%99%94%EB%AC%BC
# [04:52:38]   ▶ 1페이지 아이템 수(page_size)=10
# [04:52:38]   ▶ 목표: page=1, page내순번=4
# [04:52:38]   ▶ 목표 페이지 아이템 수=10
# [04:52:38] 40행 결과 ▶ 가격=8800 / 상태=OK:8800 / CSS / 원문:8,800
# [04:52:39] ================================================================================
# [04:52:39] 41행 시작 ▶ 검색명='Glutaraldehyde 50wt. Solution In Water CP' / 순번='1'
# [04:52:39] 41행 ▶ 검색 시작: 'Glutaraldehyde 50wt. Solution In Water CP' / 전체 1번째
# [04:52:39]   ✔ 검색어 입력 완료: 'Glutaraldehyde 50wt. Solution In Water CP'
# [04:52:39]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:41]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Glutaraldehyde+50wt.+Solution+In+Water+CP
# [04:52:41]   ▶ 1페이지 아이템 수(page_size)=1
# [04:52:41]   ▶ 목표: page=1, page내순번=1
# [04:52:41]   ▶ 목표 페이지 아이템 수=1
# [04:52:41] 41행 결과 ▶ 가격=20680 / 상태=OK:20680 / CSS / 원문:20,680
# [04:52:42] ================================================================================
# [04:52:42] 42행 시작 ▶ 검색명='Glycerol 99 EP' / 순번='1'
# [04:52:42] 42행 ▶ 검색 시작: 'Glycerol 99 EP' / 전체 1번째
# [04:52:42]   ✔ 검색어 입력 완료: 'Glycerol 99 EP'
# [04:52:42]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:44]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Glycerol+99+EP
# [04:52:44]   ▶ 1페이지 아이템 수(page_size)=7
# [04:52:44]   ▶ 목표: page=1, page내순번=1
# [04:52:44]   ▶ 목표 페이지 아이템 수=7
# [04:52:44] 42행 결과 ▶ 가격=8690 / 상태=OK:8690 / CSS / 원문:8,690
# [04:52:45] ================================================================================
# [04:52:45] 43행 시작 ▶ 검색명='Glycerol 99 GR' / 순번='1'
# [04:52:45] 43행 ▶ 검색 시작: 'Glycerol 99 GR' / 전체 1번째
# [04:52:46]   ✔ 검색어 입력 완료: 'Glycerol 99 GR'
# [04:52:46]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:47]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Glycerol+99+GR
# [04:52:47]   ▶ 1페이지 아이템 수(page_size)=7
# [04:52:47]   ▶ 목표: page=1, page내순번=1
# [04:52:47]   ▶ 목표 페이지 아이템 수=7
# [04:52:47] 43행 결과 ▶ 가격=8910 / 상태=OK:8910 / CSS / 원문:8,910
# [04:52:48] ================================================================================
# [04:52:48] 44행 시작 ▶ 검색명='Glycerine 99 EP' / 순번='1'
# [04:52:48] 44행 ▶ 검색 시작: 'Glycerine 99 EP' / 전체 1번째
# [04:52:49]   ✔ 검색어 입력 완료: 'Glycerine 99 EP'
# [04:52:49]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:51]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Glycerine+99+EP
# [04:52:51]   ▶ 1페이지 아이템 수(page_size)=4
# [04:52:51]   ▶ 목표: page=1, page내순번=1
# [04:52:51]   ▶ 목표 페이지 아이템 수=4
# [04:52:51] 44행 결과 ▶ 가격=8690 / 상태=OK:8690 / CSS / 원문:8,690
# [04:52:52] ================================================================================
# [04:52:52] 45행 시작 ▶ 검색명='Glycine Aminoacetic Acid 99 GR' / 순번='첫번째 품목 안에 규격별 가격 보고 해야함'
# [04:52:52] 45행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(첫번째 품목 안에 규격별 가격 보고 해야함)
# [04:52:53] ================================================================================
# [04:52:53] 46행 시작 ▶ 검색명='Sodium Metal EP' / 순번='1'
# [04:52:53] 46행 ▶ 검색 시작: 'Sodium Metal EP' / 전체 1번째
# [04:52:53]   ✔ 검색어 입력 완료: 'Sodium Metal EP'
# [04:52:53]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:55]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Metal+EP
# [04:52:55]   ▶ 1페이지 아이템 수(page_size)=5
# [04:52:55]   ▶ 목표: page=1, page내순번=1
# [04:52:55]   ▶ 목표 페이지 아이템 수=5
# [04:52:55] 46행 결과 ▶ 가격=39600 / 상태=OK:39600 / CSS / 원문:39,600
# [04:52:56] ================================================================================
# [04:52:56] 47행 시작 ▶ 검색명='Naphthalene  EP  나프탈렌' / 순번='1'
# [04:52:56] 47행 ▶ 검색 시작: 'Naphthalene  EP  나프탈렌' / 전체 1번째
# [04:52:56]   ✔ 검색어 입력 완료: 'Naphthalene  EP  나프탈렌'
# [04:52:56]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:52:58]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Naphthalene++EP++%EB%82%98%ED%94%84%ED%83%88%EB%A0%8C
# [04:52:58]   ▶ 1페이지 아이템 수(page_size)=3
# [04:52:58]   ▶ 목표: page=1, page내순번=1
# [04:52:58]   ▶ 목표 페이지 아이템 수=3
# [04:52:58] 47행 결과 ▶ 가격=8250 / 상태=OK:8250 / CSS / 원문:8,250
# [04:52:59] ================================================================================
# [04:52:59] 48행 시작 ▶ 검색명='Dichloromethane Methylene chloride MC  99.5  EP  디클로로메탄염화메틸렌' / 순번='2'
# [04:52:59] 48행 ▶ 검색 시작: 'Dichloromethane Methylene chloride MC  99.5  EP  디클로로메탄염화메틸렌' / 전체 2번째
# [04:52:59]   ✔ 검색어 입력 완료: 'Dichloromethane Methylene chloride MC  99.5  EP  디클로로메탄염화메틸렌'
# [04:52:59]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:01]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Dichloromethane+Methylene+chloride+MC++99.5++EP++%EB%94%94%ED%81%B4%EB%A1%9C%EB%A1%9C%EB%A9%94%ED%83%84%EC%97%BC%ED%99%94%EB%A9%94%ED%8B%B8%EB%A0%8C
# [04:53:01]   ▶ 1페이지 아이템 수(page_size)=27
# [04:53:01]   ▶ 목표: page=1, page내순번=2
# [04:53:01]   ▶ 목표 페이지 아이템 수=27
# [04:53:01] 48행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:53:02] ================================================================================
# [04:53:02] 49행 시작 ▶ 검색명='Methyl Alcohol 99.8 GR' / 순번='2'
# [04:53:02] 49행 ▶ 검색 시작: 'Methyl Alcohol 99.8 GR' / 전체 2번째
# [04:53:03]   ✔ 검색어 입력 완료: 'Methyl Alcohol 99.8 GR'
# [04:53:03]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:04]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Methyl+Alcohol+99.8+GR
# [04:53:04]   ▶ 1페이지 아이템 수(page_size)=8
# [04:53:04]   ▶ 목표: page=1, page내순번=2
# [04:53:04]   ▶ 목표 페이지 아이템 수=8
# [04:53:04] 49행 결과 ▶ 가격=5500 / 상태=OK:5500 / CSS / 원문:5,500
# [04:53:06] ================================================================================
# [04:53:06] 50행 시작 ▶ 검색명='Methyl alcohol  99.5  EP  메틸알콜' / 순번='1'
# [04:53:06] 50행 ▶ 검색 시작: 'Methyl alcohol  99.5  EP  메틸알콜' / 전체 1번째
# [04:53:06]   ✔ 검색어 입력 완료: 'Methyl alcohol  99.5  EP  메틸알콜'
# [04:53:06]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:08]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Methyl+alcohol++99.5++EP++%EB%A9%94%ED%8B%B8%EC%95%8C%EC%BD%9C
# [04:53:08]   ▶ 1페이지 아이템 수(page_size)=4
# [04:53:08]   ▶ 목표: page=1, page내순번=1
# [04:53:08]   ▶ 목표 페이지 아이템 수=4
# [04:53:08] 50행 결과 ▶ 가격=4840 / 상태=OK:4840 / CSS / 원문:4,840
# [04:53:09] ================================================================================
# [04:53:09] 51행 시작 ▶ 검색명='Methyl Ethyl Ketone MEK 2-Butanone 99.5 EP' / 순번='2'
# [04:53:09] 51행 ▶ 검색 시작: 'Methyl Ethyl Ketone MEK 2-Butanone 99.5 EP' / 전체 2번째
# [04:53:09]   ✔ 검색어 입력 완료: 'Methyl Ethyl Ketone MEK 2-Butanone 99.5 EP'
# [04:53:09]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:11]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Methyl+Ethyl+Ketone+MEK+2-Butanone+99.5+EP
# [04:53:11]   ▶ 1페이지 아이템 수(page_size)=13
# [04:53:11]   ▶ 목표: page=1, page내순번=2
# [04:53:11]   ▶ 목표 페이지 아이템 수=13
# [04:53:11] 51행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:53:12] ================================================================================
# [04:53:12] 52행 시작 ▶ 검색명='Calcium Chloride Anhydrous 96' / 순번='1'
# [04:53:12] 52행 ▶ 검색 시작: 'Calcium Chloride Anhydrous 96' / 전체 1번째
# [04:53:12]   ✔ 검색어 입력 완료: 'Calcium Chloride Anhydrous 96'
# [04:53:12]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:14]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Calcium+Chloride+Anhydrous+96
# [04:53:14]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:14]   ▶ 목표: page=1, page내순번=1
# [04:53:14]   ▶ 목표 페이지 아이템 수=1
# [04:53:14] 52행 결과 ▶ 가격=8690 / 상태=OK:8690 / CSS / 원문:8,690
# [04:53:15] ================================================================================
# [04:53:15] 53행 시작 ▶ 검색명='Mineral oil  EP  미네랄오일' / 순번='2'
# [04:53:15] 53행 ▶ 검색 시작: 'Mineral oil  EP  미네랄오일' / 전체 2번째
# [04:53:15]   ✔ 검색어 입력 완료: 'Mineral oil  EP  미네랄오일'
# [04:53:15]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:17]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Mineral+oil++EP++%EB%AF%B8%EB%84%A4%EB%9E%84%EC%98%A4%EC%9D%BC
# [04:53:17]   ▶ 1페이지 아이템 수(page_size)=3
# [04:53:17]   ▶ 목표: page=1, page내순번=2
# [04:53:17]   ▶ 목표 페이지 아이템 수=3
# [04:53:17] 53행 결과 ▶ 가격=16500 / 상태=OK:16500 / CSS / 원문:16,500
# [04:53:18] ================================================================================
# [04:53:18] 54행 시작 ▶ 검색명='Salicylic Acid 99 EP' / 순번='두번째 품목 안에 규격별 가격 보고 해야함'
# [04:53:18] 54행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(두번째 품목 안에 규격별 가격 보고 해야함)
# [04:53:19] ================================================================================
# [04:53:19] 55행 시작 ▶ 검색명='0.1mol L-Sodium Hydroxide Solution' / 순번='1'
# [04:53:19] 55행 ▶ 검색 시작: '0.1mol L-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:20]   ✔ 검색어 입력 완료: '0.1mol L-Sodium Hydroxide Solution'
# [04:53:20]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:21]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.1mol+L-Sodium+Hydroxide+Solution
# [04:53:21]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:21]   ▶ 목표: page=1, page내순번=1
# [04:53:21]   ▶ 목표 페이지 아이템 수=1
# [04:53:21] 55행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:53:22] ================================================================================
# [04:53:22] 56행 시작 ▶ 검색명='0.5mol L-Sodium Hydroxide Solution' / 순번='1'
# [04:53:22] 56행 ▶ 검색 시작: '0.5mol L-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:23]   ✔ 검색어 입력 완료: '0.5mol L-Sodium Hydroxide Solution'
# [04:53:23]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:24]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.5mol+L-Sodium+Hydroxide+Solution
# [04:53:24]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:24]   ▶ 목표: page=1, page내순번=1
# [04:53:24]   ▶ 목표 페이지 아이템 수=1
# [04:53:24] 56행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:53:25] ================================================================================
# [04:53:25] 57행 시작 ▶ 검색명='Sodium Hydroxide 93 EP' / 순번='1'
# [04:53:25] 57행 ▶ 검색 시작: 'Sodium Hydroxide 93 EP' / 전체 1번째
# [04:53:26]   ✔ 검색어 입력 완료: 'Sodium Hydroxide 93 EP'
# [04:53:26]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:27]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Hydroxide+93+EP
# [04:53:27]   ▶ 1페이지 아이템 수(page_size)=5
# [04:53:27]   ▶ 목표: page=1, page내순번=1
# [04:53:27]   ▶ 목표 페이지 아이템 수=5
# [04:53:27] 57행 결과 ▶ 가격=6930 / 상태=OK:6930 / CSS / 원문:6,930
# [04:53:28] ================================================================================
# [04:53:28] 58행 시작 ▶ 검색명='Sodium Hydroxide Bead powder 97 EP' / 순번='1'
# [04:53:28] 58행 ▶ 검색 시작: 'Sodium Hydroxide Bead powder 97 EP' / 전체 1번째
# [04:53:28]   ✔ 검색어 입력 완료: 'Sodium Hydroxide Bead powder 97 EP'
# [04:53:28]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:30]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Hydroxide+Bead+powder+97+EP
# [04:53:30]   ▶ 1페이지 아이템 수(page_size)=3
# [04:53:30]   ▶ 목표: page=1, page내순번=1
# [04:53:30]   ▶ 목표 페이지 아이템 수=3
# [04:53:30] 58행 결과 ▶ 가격=6930 / 상태=OK:6930 / CSS / 원문:6,930
# [04:53:31] ================================================================================
# [04:53:31] 59행 시작 ▶ 검색명='0.01mol L-Sodium Hydroxide Solution' / 순번='1'
# [04:53:31] 59행 ▶ 검색 시작: '0.01mol L-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:32]   ✔ 검색어 입력 완료: '0.01mol L-Sodium Hydroxide Solution'
# [04:53:32]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:33]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.01mol+L-Sodium+Hydroxide+Solution
# [04:53:33]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:33]   ▶ 목표: page=1, page내순번=1
# [04:53:33]   ▶ 목표 페이지 아이템 수=1
# [04:53:33] 59행 결과 ▶ 가격=10340 / 상태=OK:10340 / CSS / 원문:10,340
# [04:53:34] ================================================================================
# [04:53:34] 60행 시작 ▶ 검색명='0.02mol L-Sodium Hydroxide Solution' / 순번='1'
# [04:53:34] 60행 ▶ 검색 시작: '0.02mol L-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:35]   ✔ 검색어 입력 완료: '0.02mol L-Sodium Hydroxide Solution'
# [04:53:35]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:36]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.02mol+L-Sodium+Hydroxide+Solution
# [04:53:37]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:37]   ▶ 목표: page=1, page내순번=1
# [04:53:37]   ▶ 목표 페이지 아이템 수=1
# [04:53:37] 60행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:53:37] ================================================================================
# [04:53:37] 61행 시작 ▶ 검색명='0.05mol, L-Sodium Hydroxide Solution' / 순번='1'
# [04:53:37] 61행 ▶ 검색 시작: '0.05mol, L-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:38]   ✔ 검색어 입력 완료: '0.05mol, L-Sodium Hydroxide Solution'
# [04:53:38]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:39]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.05mol%2C+L-Sodium+Hydroxide+Solution
# [04:53:39]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:39]   ▶ 목표: page=1, page내순번=1
# [04:53:39]   ▶ 목표 페이지 아이템 수=1
# [04:53:39] 61행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:53:40] ================================================================================
# [04:53:40] 62행 시작 ▶ 검색명='0.1mol Sodium Hydroxide Standard Solution' / 순번='1'
# [04:53:40] 62행 ▶ 검색 시작: '0.1mol Sodium Hydroxide Standard Solution' / 전체 1번째
# [04:53:41]   ✔ 검색어 입력 완료: '0.1mol Sodium Hydroxide Standard Solution'
# [04:53:41]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:42]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.1mol+Sodium+Hydroxide+Standard+Solution
# [04:53:42]   ▶ 1페이지 아이템 수(page_size)=2
# [04:53:42]   ▶ 목표: page=1, page내순번=1
# [04:53:42]   ▶ 목표 페이지 아이템 수=2
# [04:53:43] 62행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:53:43] ================================================================================
# [04:53:43] 63행 시작 ▶ 검색명='0.2mol, L-Sodium Hydroxide Solution' / 순번='1'
# [04:53:43] 63행 ▶ 검색 시작: '0.2mol, L-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:44]   ✔ 검색어 입력 완료: '0.2mol, L-Sodium Hydroxide Solution'
# [04:53:44]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:45]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.2mol%2C+L-Sodium+Hydroxide+Solution
# [04:53:45]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:45]   ▶ 목표: page=1, page내순번=1
# [04:53:45]   ▶ 목표 페이지 아이템 수=1
# [04:53:46] 63행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:53:46] ================================================================================
# [04:53:46] 64행 시작 ▶ 검색명='2molL-Sodium hydroxide solution 2N  수산화나트륨용액' / 순번='2'
# [04:53:47] 64행 ▶ 검색 시작: '2molL-Sodium hydroxide solution 2N  수산화나트륨용액' / 전체 2번째
# [04:53:47]   ✔ 검색어 입력 완료: '2molL-Sodium hydroxide solution 2N  수산화나트륨용액'
# [04:53:47]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:49]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=2molL-Sodium+hydroxide+solution+2N++%EC%88%98%EC%82%B0%ED%99%94%EB%82%98%ED%8A%B8%EB%A5%A8%EC%9A%A9%EC%95%A1
# [04:53:49]   ▶ 1페이지 아이템 수(page_size)=3
# [04:53:49]   ▶ 목표: page=1, page내순번=2
# [04:53:49]   ▶ 목표 페이지 아이템 수=3
# [04:53:49] 64행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:53:50] ================================================================================
# [04:53:50] 65행 시작 ▶ 검색명='4mol l-Sodium Hydroxide Solution' / 순번='1'
# [04:53:50] 65행 ▶ 검색 시작: '4mol l-Sodium Hydroxide Solution' / 전체 1번째
# [04:53:51]   ✔ 검색어 입력 완료: '4mol l-Sodium Hydroxide Solution'
# [04:53:51]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:52]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=4mol+l-Sodium+Hydroxide+Solution
# [04:53:52]   ▶ 1페이지 아이템 수(page_size)=1
# [04:53:52]   ▶ 목표: page=1, page내순번=1
# [04:53:52]   ▶ 목표 페이지 아이템 수=1
# [04:53:52] 65행 결과 ▶ 가격=13200 / 상태=OK:13200 / CSS / 원문:13,200
# [04:53:53] ================================================================================
# [04:53:53] 66행 시작 ▶ 검색명='Magnesium Hydroxide 95 EP' / 순번='1'
# [04:53:53] 66행 ▶ 검색 시작: 'Magnesium Hydroxide 95 EP' / 전체 1번째
# [04:53:54]   ✔ 검색어 입력 완료: 'Magnesium Hydroxide 95 EP'
# [04:53:54]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:55]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Magnesium+Hydroxide+95+EP
# [04:53:55]   ▶ 1페이지 아이템 수(page_size)=3
# [04:53:55]   ▶ 목표: page=1, page내순번=1
# [04:53:55]   ▶ 목표 페이지 아이템 수=3
# [04:53:55] 66행 결과 ▶ 가격=8910 / 상태=OK:8910 / CSS / 원문:8,910
# [04:53:56] ================================================================================
# [04:53:56] 67행 시작 ▶ 검색명='Potassium Hydroxide Flakes 93 EP' / 순번='1'
# [04:53:56] 67행 ▶ 검색 시작: 'Potassium Hydroxide Flakes 93 EP' / 전체 1번째
# [04:53:56]   ✔ 검색어 입력 완료: 'Potassium Hydroxide Flakes 93 EP'
# [04:53:56]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:53:58]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Potassium+Hydroxide+Flakes+93+EP
# [04:53:58]   ▶ 1페이지 아이템 수(page_size)=2
# [04:53:58]   ▶ 목표: page=1, page내순번=1
# [04:53:58]   ▶ 목표 페이지 아이템 수=2
# [04:53:58] 67행 결과 ▶ 가격=8250 / 상태=OK:8250 / CSS / 원문:8,250
# [04:53:59] ================================================================================
# [04:53:59] 68행 시작 ▶ 검색명='Potassium Hydroxide 85 EP' / 순번='첫번째 품목 안에 규격별 가격 보고 해야함'
# [04:53:59] 68행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(첫번째 품목 안에 규격별 가격 보고 해야함)
# [04:54:00] ================================================================================
# [04:54:00] 69행 시작 ▶ 검색명='0.1mol 0.1N Potassium Hydroxide Standard Solution' / 순번='1'
# [04:54:00] 69행 ▶ 검색 시작: '0.1mol 0.1N Potassium Hydroxide Standard Solution' / 전체 1번째
# [04:54:00]   ✔ 검색어 입력 완료: '0.1mol 0.1N Potassium Hydroxide Standard Solution'
# [04:54:00]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:02]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.1mol+0.1N+Potassium+Hydroxide+Standard+Solution
# [04:54:02]   ▶ 1페이지 아이템 수(page_size)=2
# [04:54:02]   ▶ 목표: page=1, page내순번=1
# [04:54:02]   ▶ 목표 페이지 아이템 수=2
# [04:54:02] 69행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:54:03] ================================================================================
# [04:54:03] 70행 시작 ▶ 검색명='Agar EP' / 순번='1'
# [04:54:03] 70행 ▶ 검색 시작: 'Agar EP' / 전체 1번째
# [04:54:04]   ✔ 검색어 입력 완료: 'Agar EP'
# [04:54:04]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:05]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Agar+EP
# [04:54:06]   ▶ 1페이지 아이템 수(page_size)=30
# [04:54:06]   ▶ 목표: page=1, page내순번=1
# [04:54:06]   ▶ 목표 페이지 아이템 수=30
# [04:54:06] 70행 결과 ▶ 가격=41250 / 상태=OK:41250 / CSS / 원문:41,250
# [04:54:06] ================================================================================
# [04:54:06] 71행 시작 ▶ 검색명='Acetone 99.5 EP' / 순번='1'
# [04:54:06] 71행 ▶ 검색 시작: 'Acetone 99.5 EP' / 전체 1번째
# [04:54:07]   ✔ 검색어 입력 완료: 'Acetone 99.5 EP'
# [04:54:07]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:08]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetone+99.5+EP
# [04:54:09]   ▶ 1페이지 아이템 수(page_size)=6
# [04:54:09]   ▶ 목표: page=1, page내순번=1
# [04:54:09]   ▶ 목표 페이지 아이템 수=6
# [04:54:09] 71행 결과 ▶ 가격=5830 / 상태=OK:5830 / CSS / 원문:5,830
# [04:54:09] ================================================================================
# [04:54:09] 72행 시작 ▶ 검색명='Acetone 99.8 GR' / 순번='1'
# [04:54:09] 72행 ▶ 검색 시작: 'Acetone 99.8 GR' / 전체 1번째
# [04:54:10]   ✔ 검색어 입력 완료: 'Acetone 99.8 GR'
# [04:54:10]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:11]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetone+99.8+GR
# [04:54:11]   ▶ 1페이지 아이템 수(page_size)=2
# [04:54:11]   ▶ 목표: page=1, page내순번=1
# [04:54:11]   ▶ 목표 페이지 아이템 수=2
# [04:54:11] 72행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:54:12] ================================================================================
# [04:54:12] 73행 시작 ▶ 검색명='Acetone, 99.7%, GR' / 순번='1'
# [04:54:12] 73행 ▶ 검색 시작: 'Acetone, 99.7%, GR' / 전체 1번째
# [04:54:13]   ✔ 검색어 입력 완료: 'Acetone, 99.7%, GR'
# [04:54:13]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:14]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetone%2C+99.7%25%2C+GR
# [04:54:14]   ▶ 1페이지 아이템 수(page_size)=2
# [04:54:14]   ▶ 목표: page=1, page내순번=1
# [04:54:14]   ▶ 목표 페이지 아이템 수=2
# [04:54:14] 73행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:54:15] ================================================================================
# [04:54:15] 74행 시작 ▶ 검색명='Acetic acid, 99.5%, EP' / 순번='3'
# [04:54:15] 74행 ▶ 검색 시작: 'Acetic acid, 99.5%, EP' / 전체 3번째
# [04:54:16]   ✔ 검색어 입력 완료: 'Acetic acid, 99.5%, EP'
# [04:54:16]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:17]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetic+acid%2C+99.5%25%2C+EP
# [04:54:17]   ▶ 1페이지 아이템 수(page_size)=6
# [04:54:17]   ▶ 목표: page=1, page내순번=3
# [04:54:17]   ▶ 목표 페이지 아이템 수=6
# [04:54:17] 74행 결과 ▶ 가격=9350 / 상태=OK:9350 / CSS / 원문:9,350
# [04:54:19] ================================================================================
# [04:54:19] 75행 시작 ▶ 검색명='Acetic Acid Glacial 99 EP' / 순번='1'
# [04:54:19] 75행 ▶ 검색 시작: 'Acetic Acid Glacial 99 EP' / 전체 1번째
# [04:54:19]   ✔ 검색어 입력 완료: 'Acetic Acid Glacial 99 EP'
# [04:54:20]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:21]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetic+Acid+Glacial+99+EP
# [04:54:21]   ▶ 1페이지 아이템 수(page_size)=5
# [04:54:21]   ▶ 목표: page=1, page내순번=1
# [04:54:21]   ▶ 목표 페이지 아이템 수=5
# [04:54:21] 75행 결과 ▶ 가격=10340 / 상태=OK:10340 / CSS / 원문:10,340
# [04:54:22] ================================================================================
# [04:54:22] 76행 시작 ▶ 검색명='Acetic Acid glacial 99.7 GR' / 순번='1'
# [04:54:22] 76행 ▶ 검색 시작: 'Acetic Acid glacial 99.7 GR' / 전체 1번째
# [04:54:23]   ✔ 검색어 입력 완료: 'Acetic Acid glacial 99.7 GR'
# [04:54:23]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:54:24]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Acetic+Acid+glacial+99.7+GR
# [04:54:24]   ▶ 1페이지 아이템 수(page_size)=3
# [04:54:24]   ▶ 목표: page=1, page내순번=1
# [04:54:24]   ▶ 목표 페이지 아이템 수=3
# ...
# [04:56:08]   ▶ 목표: page=1, page내순번=1
# [04:56:08]   ▶ 목표 페이지 아이템 수=1
# [04:56:08] 111행 결과 ▶ 가격=19800 / 상태=OK:19800 / CSS / 원문:19,800
# [04:56:09] ================================================================================
# [04:56:09] 112행 시작 ▶ 검색명='Ammonium Nitrate  99  EP  질산암모늄' / 순번='1'
# [04:56:09] 112행 ▶ 검색 시작: 'Ammonium Nitrate  99  EP  질산암모늄' / 전체 1번째
# [04:56:10]   ✔ 검색어 입력 완료: 'Ammonium Nitrate  99  EP  질산암모늄'
# [04:56:10]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:11]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Ammonium+Nitrate++99++EP++%EC%A7%88%EC%82%B0%EC%95%94%EB%AA%A8%EB%8A%84
# [04:56:11]   ▶ 1페이지 아이템 수(page_size)=3
# [04:56:11]   ▶ 목표: page=1, page내순번=1
# [04:56:11]   ▶ 목표 페이지 아이템 수=3
# [04:56:11] 112행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:56:12] ================================================================================
# [04:56:12] 113행 시작 ▶ 검색명='Silver I nitrate  99.8  GR  질산은' / 순번='첫번째 품목 안에 규격별 가격 보고 해야함'
# [04:56:12] 113행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(첫번째 품목 안에 규격별 가격 보고 해야함)
# [04:56:13] ================================================================================
# [04:56:13] 114행 시작 ▶ 검색명='0.1mol 0.1N Silver I Nitrate Standard Solution' / 순번='1'
# [04:56:13] 114행 ▶ 검색 시작: '0.1mol 0.1N Silver I Nitrate Standard Solution' / 전체 1번째
# [04:56:14]   ✔ 검색어 입력 완료: '0.1mol 0.1N Silver I Nitrate Standard Solution'
# [04:56:14]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:15]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=0.1mol+0.1N+Silver+I+Nitrate+Standard+Solution
# [04:56:15]   ▶ 1페이지 아이템 수(page_size)=2
# [04:56:15]   ▶ 목표: page=1, page내순번=1
# [04:56:15]   ▶ 목표 페이지 아이템 수=2
# [04:56:15] 114행 결과 ▶ 가격=48180 / 상태=OK:48180 / CSS / 원문:48,180
# [04:56:16] ================================================================================
# [04:56:16] 115행 시작 ▶ 검색명='0.1mol L-Silver Nitrate Solution' / 순번='첫번째 품목 안에 규격별 가격 보고 해야함'
# [04:56:16] 115행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(첫번째 품목 안에 규격별 가격 보고 해야함)
# [04:56:17] ================================================================================
# [04:56:17] 116행 시작 ▶ 검색명='Potassium Nitrate 99 EP' / 순번='1'
# [04:56:17] 116행 ▶ 검색 시작: 'Potassium Nitrate 99 EP' / 전체 1번째
# [04:56:18]   ✔ 검색어 입력 완료: 'Potassium Nitrate 99 EP'
# [04:56:18]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:19]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Potassium+Nitrate+99+EP
# [04:56:20]   ▶ 1페이지 아이템 수(page_size)=4
# [04:56:20]   ▶ 목표: page=1, page내순번=1
# [04:56:20]   ▶ 목표 페이지 아이템 수=4
# [04:56:20] 116행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:56:20] ================================================================================
# [04:56:20] 117행 시작 ▶ 검색명='Sodium Hypochlorite Solution 6 14' / 순번='2'
# [04:56:20] 117행 ▶ 검색 시작: 'Sodium Hypochlorite Solution 6 14' / 전체 2번째
# [04:56:21]   ✔ 검색어 입력 완료: 'Sodium Hypochlorite Solution 6 14'
# [04:56:21]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:23]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Hypochlorite+Solution+6+14
# [04:56:23]   ▶ 1페이지 아이템 수(page_size)=7
# [04:56:23]   ▶ 목표: page=1, page내순번=2
# [04:56:23]   ▶ 목표 페이지 아이템 수=7
# [04:56:23] 117행 결과 ▶ 가격=4840 / 상태=OK:4840 / CSS / 원문:4,840
# [04:56:23] ================================================================================
# [04:56:23] 118행 시작 ▶ 검색명='Potassium Acetate 97 EP' / 순번='1'
# [04:56:23] 118행 ▶ 검색 시작: 'Potassium Acetate 97 EP' / 전체 1번째
# [04:56:24]   ✔ 검색어 입력 완료: 'Potassium Acetate 97 EP'
# [04:56:24]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:25]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Potassium+Acetate+97+EP
# [04:56:25]   ▶ 1페이지 아이템 수(page_size)=2
# [04:56:25]   ▶ 목표: page=1, page내순번=1
# [04:56:25]   ▶ 목표 페이지 아이템 수=2
# [04:56:25] 118행 결과 ▶ 가격=11000 / 상태=OK:11000 / CSS / 원문:11,000
# [04:56:26] ================================================================================
# [04:56:26] 119행 시작 ▶ 검색명='Chloroform 99.5 EP' / 순번='1'
# [04:56:26] 119행 ▶ 검색 시작: 'Chloroform 99.5 EP' / 전체 1번째
# [04:56:27]   ✔ 검색어 입력 완료: 'Chloroform 99.5 EP'
# [04:56:27]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:28]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Chloroform+99.5+EP
# [04:56:28]   ▶ 1페이지 아이템 수(page_size)=4
# [04:56:28]   ▶ 목표: page=1, page내순번=1
# [04:56:28]   ▶ 목표 페이지 아이템 수=4
# [04:56:28] 119행 결과 ▶ 가격=6600 / 상태=OK:6600 / CSS / 원문:6,600
# [04:56:29] ================================================================================
# [04:56:29] 120행 시작 ▶ 검색명='Chloroform  99  EP  클로로포름' / 순번='6'
# [04:56:29] 120행 ▶ 검색 시작: 'Chloroform  99  EP  클로로포름' / 전체 6번째
# [04:56:30]   ✔ 검색어 입력 완료: 'Chloroform  99  EP  클로로포름'
# [04:56:30]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:31]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Chloroform++99++EP++%ED%81%B4%EB%A1%9C%EB%A1%9C%ED%8F%AC%EB%A6%84
# [04:56:32]   ▶ 1페이지 아이템 수(page_size)=6
# [04:56:32]   ▶ 목표: page=1, page내순번=6
# [04:56:32]   ▶ 목표 페이지 아이템 수=6
# [04:56:32] 120행 결과 ▶ 가격=9460 / 상태=OK:9460 / CSS / 원문:9,460
# [04:56:33] ================================================================================
# [04:56:33] 121행 시작 ▶ 검색명='Chloroform 99.8 GR' / 순번='1'
# [04:56:33] 121행 ▶ 검색 시작: 'Chloroform 99.8 GR' / 전체 1번째
# [04:56:34]   ✔ 검색어 입력 완료: 'Chloroform 99.8 GR'
# [04:56:34]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:35]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Chloroform+99.8+GR
# [04:56:35]   ▶ 1페이지 아이템 수(page_size)=2
# [04:56:35]   ▶ 목표: page=1, page내순번=1
# [04:56:35]   ▶ 목표 페이지 아이템 수=2
# [04:56:35] 121행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:56:36] ================================================================================
# [04:56:36] 122행 시작 ▶ 검색명='Sodium Carbonate Anhydrous 99.5 GR' / 순번='2'
# [04:56:36] 122행 ▶ 검색 시작: 'Sodium Carbonate Anhydrous 99.5 GR' / 전체 2번째
# [04:56:37]   ✔ 검색어 입력 완료: 'Sodium Carbonate Anhydrous 99.5 GR'
# [04:56:37]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:38]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Carbonate+Anhydrous+99.5+GR
# [04:56:38]   ▶ 1페이지 아이템 수(page_size)=12
# [04:56:38]   ▶ 목표: page=1, page내순번=2
# [04:56:38]   ▶ 목표 페이지 아이템 수=12
# [04:56:38] 122행 결과 ▶ 가격=11000 / 상태=OK:11000 / CSS / 원문:11,000
# [04:56:39] ================================================================================
# [04:56:39] 123행 시작 ▶ 검색명='Sodium Hydrogen Carbonate Sodium Bicarbonate 99 100.5 EP' / 순번='1'
# [04:56:39] 123행 ▶ 검색 시작: 'Sodium Hydrogen Carbonate Sodium Bicarbonate 99 100.5 EP' / 전체 1번째
# [04:56:40]   ✔ 검색어 입력 완료: 'Sodium Hydrogen Carbonate Sodium Bicarbonate 99 100.5 EP'
# [04:56:40]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:41]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sodium+Hydrogen+Carbonate+Sodium+Bicarbonate+99+100.5+EP
# [04:56:41]   ▶ 1페이지 아이템 수(page_size)=10
# [04:56:41]   ▶ 목표: page=1, page내순번=1
# [04:56:41]   ▶ 목표 페이지 아이템 수=10
# [04:56:41] 123행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:56:42] ================================================================================
# [04:56:42] 124행 시작 ▶ 검색명='Toluene 99.8 GR' / 순번='1'
# [04:56:42] 124행 ▶ 검색 시작: 'Toluene 99.8 GR' / 전체 1번째
# [04:56:43]   ✔ 검색어 입력 완료: 'Toluene 99.8 GR'
# [04:56:43]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:44]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Toluene+99.8+GR
# [04:56:44]   ▶ 1페이지 아이템 수(page_size)=2
# [04:56:44]   ▶ 목표: page=1, page내순번=1
# [04:56:44]   ▶ 목표 페이지 아이템 수=2
# [04:56:44] 124행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:56:45] ================================================================================
# [04:56:45] 125행 시작 ▶ 검색명='Toluene 99.5 EP' / 순번='1'
# [04:56:45] 125행 ▶ 검색 시작: 'Toluene 99.5 EP' / 전체 1번째
# [04:56:46]   ✔ 검색어 입력 완료: 'Toluene 99.5 EP'
# [04:56:46]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:48]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Toluene+99.5+EP
# [04:56:48]   ▶ 1페이지 아이템 수(page_size)=6
# [04:56:48]   ▶ 목표: page=1, page내순번=1
# [04:56:48]   ▶ 목표 페이지 아이템 수=6
# [04:56:48] 125행 결과 ▶ 가격=9680 / 상태=OK:9680 / CSS / 원문:9,680
# [04:56:49] ================================================================================
# [04:56:49] 126행 시작 ▶ 검색명='Phenol  99  EP  페놀' / 순번='두번째 품목 안에 규격별 가격 보고 해야함'
# [04:56:49] 126행 결과 ▶ 가격=None / 상태=FAIL:순번 정수 변환 실패(두번째 품목 안에 규격별 가격 보고 해야함)
# [04:56:50] ================================================================================
# [04:56:50] 127행 시작 ▶ 검색명='Formaldehyde 35 EP' / 순번='1'
# [04:56:50] 127행 ▶ 검색 시작: 'Formaldehyde 35 EP' / 전체 1번째
# [04:56:50]   ✔ 검색어 입력 완료: 'Formaldehyde 35 EP'
# [04:56:50]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:52]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Formaldehyde+35+EP
# [04:56:52]   ▶ 1페이지 아이템 수(page_size)=5
# [04:56:52]   ▶ 목표: page=1, page내순번=1
# [04:56:52]   ▶ 목표 페이지 아이템 수=5
# [04:56:52] 127행 결과 ▶ 가격=10340 / 상태=OK:10340 / CSS / 원문:10,340
# [04:56:53] ================================================================================
# [04:56:53] 128행 시작 ▶ 검색명='Buffer Solution pH 10.00' / 순번='1'
# [04:56:53] 128행 ▶ 검색 시작: 'Buffer Solution pH 10.00' / 전체 1번째
# [04:56:53]   ✔ 검색어 입력 완료: 'Buffer Solution pH 10.00'
# [04:56:53]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:55]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Buffer+Solution+pH+10.00
# [04:56:55]   ▶ 1페이지 아이템 수(page_size)=3
# [04:56:55]   ▶ 목표: page=1, page내순번=1
# [04:56:55]   ▶ 목표 페이지 아이템 수=3
# [04:56:55] 128행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:56:56] ================================================================================
# [04:56:56] 129행 시작 ▶ 검색명='Buffer Solution pH 4.00' / 순번='1'
# [04:56:56] 129행 ▶ 검색 시작: 'Buffer Solution pH 4.00' / 전체 1번째
# [04:56:56]   ✔ 검색어 입력 완료: 'Buffer Solution pH 4.00'
# [04:56:56]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:56:58]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Buffer+Solution+pH+4.00
# [04:56:58]   ▶ 1페이지 아이템 수(page_size)=2
# [04:56:58]   ▶ 목표: page=1, page내순번=1
# [04:56:58]   ▶ 목표 페이지 아이템 수=2
# [04:56:58] 129행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:56:58] ================================================================================
# [04:56:58] 130행 시작 ▶ 검색명='Buffer Solution pH 4.01' / 순번='2'
# [04:56:58] 130행 ▶ 검색 시작: 'Buffer Solution pH 4.01' / 전체 2번째
# [04:56:59]   ✔ 검색어 입력 완료: 'Buffer Solution pH 4.01'
# [04:56:59]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:01]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Buffer+Solution+pH+4.01
# [04:57:01]   ▶ 1페이지 아이템 수(page_size)=6
# [04:57:01]   ▶ 목표: page=1, page내순번=2
# [04:57:01]   ▶ 목표 페이지 아이템 수=6
# [04:57:01] 130행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:57:02] ================================================================================
# [04:57:02] 131행 시작 ▶ 검색명='Buffer Solution pH 6.86' / 순번='2'
# [04:57:02] 131행 ▶ 검색 시작: 'Buffer Solution pH 6.86' / 전체 2번째
# [04:57:03]   ✔ 검색어 입력 완료: 'Buffer Solution pH 6.86'
# [04:57:03]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:04]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Buffer+Solution+pH+6.86
# [04:57:04]   ▶ 1페이지 아이템 수(page_size)=5
# [04:57:04]   ▶ 목표: page=1, page내순번=2
# [04:57:04]   ▶ 목표 페이지 아이템 수=5
# [04:57:04] 131행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:57:05] ================================================================================
# [04:57:05] 132행 시작 ▶ 검색명='Buffer solution pH 7.00  표준완충용액' / 순번='2'
# [04:57:05] 132행 ▶ 검색 시작: 'Buffer solution pH 7.00  표준완충용액' / 전체 2번째
# [04:57:06]   ✔ 검색어 입력 완료: 'Buffer solution pH 7.00  표준완충용액'
# [04:57:06]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:07]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Buffer+solution+pH+7.00++%ED%91%9C%EC%A4%80%EC%99%84%EC%B6%A9%EC%9A%A9%EC%95%A1
# [04:57:07]   ▶ 1페이지 아이템 수(page_size)=2
# [04:57:07]   ▶ 목표: page=1, page내순번=2
# [04:57:07]   ▶ 목표 페이지 아이템 수=2
# [04:57:07] 132행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:57:08] ================================================================================
# [04:57:08] 133행 시작 ▶ 검색명='n-Hexane 95 EP' / 순번='3'
# [04:57:08] 133행 ▶ 검색 시작: 'n-Hexane 95 EP' / 전체 3번째
# [04:57:09]   ✔ 검색어 입력 완료: 'n-Hexane 95 EP'
# [04:57:09]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:10]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=n-Hexane+95+EP
# [04:57:10]   ▶ 1페이지 아이템 수(page_size)=5
# [04:57:10]   ▶ 목표: page=1, page내순번=3
# [04:57:10]   ▶ 목표 페이지 아이템 수=5
# [04:57:10] 133행 결과 ▶ 가격=8800 / 상태=OK:8800 / CSS / 원문:8,800
# [04:57:11] ================================================================================
# [04:57:11] 134행 시작 ▶ 검색명='n-Hexane 96 GR' / 순번='2'
# [04:57:11] 134행 ▶ 검색 시작: 'n-Hexane 96 GR' / 전체 2번째
# [04:57:12]   ✔ 검색어 입력 완료: 'n-Hexane 96 GR'
# [04:57:12]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:13]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=n-Hexane+96+GR
# [04:57:13]   ▶ 1페이지 아이템 수(page_size)=3
# [04:57:13]   ▶ 목표: page=1, page내순번=2
# [04:57:13]   ▶ 목표 페이지 아이템 수=3
# [04:57:13] 134행 결과 ▶ 가격=6160 / 상태=OK:6160 / CSS / 원문:6,160
# [04:57:14] ================================================================================
# [04:57:14] 135행 시작 ▶ 검색명='Sulfuric Acid 98 GR' / 순번='2'
# [04:57:14] 135행 ▶ 검색 시작: 'Sulfuric Acid 98 GR' / 전체 2번째
# [04:57:15]   ✔ 검색어 입력 완료: 'Sulfuric Acid 98 GR'
# [04:57:15]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:16]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sulfuric+Acid+98+GR
# [04:57:16]   ▶ 1페이지 아이템 수(page_size)=5
# [04:57:16]   ▶ 목표: page=1, page내순번=2
# [04:57:16]   ▶ 목표 페이지 아이템 수=5
# [04:57:16] 135행 결과 ▶ 가격=8910 / 상태=OK:8910 / CSS / 원문:8,910
# [04:57:17] ================================================================================
# [04:57:17] 136행 시작 ▶ 검색명='Sulfuric Acid 95 GR' / 순번='1'
# [04:57:17] 136행 ▶ 검색 시작: 'Sulfuric Acid 95 GR' / 전체 1번째
# [04:57:18]   ✔ 검색어 입력 완료: 'Sulfuric Acid 95 GR'
# [04:57:18]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:20]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sulfuric+Acid+95+GR
# [04:57:20]   ▶ 1페이지 아이템 수(page_size)=4
# [04:57:20]   ▶ 목표: page=1, page내순번=1
# [04:57:20]   ▶ 목표 페이지 아이템 수=4
# [04:57:20] 136행 결과 ▶ 가격=8250 / 상태=OK:8250 / CSS / 원문:8,250
# [04:57:21] ================================================================================
# [04:57:21] 137행 시작 ▶ 검색명='Sulfuric Acid  95  EP  황산' / 순번='1'
# [04:57:21] 137행 ▶ 검색 시작: 'Sulfuric Acid  95  EP  황산' / 전체 1번째
# [04:57:21]   ✔ 검색어 입력 완료: 'Sulfuric Acid  95  EP  황산'
# [04:57:21]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:22]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Sulfuric+Acid++95++EP++%ED%99%A9%EC%82%B0
# [04:57:23]   ▶ 1페이지 아이템 수(page_size)=6
# [04:57:23]   ▶ 목표: page=1, page내순번=1
# [04:57:23]   ▶ 목표 페이지 아이템 수=6
# [04:57:23] 137행 결과 ▶ 가격=7590 / 상태=OK:7590 / CSS / 원문:7,590
# [04:57:23] ================================================================================
# [04:57:23] 138행 시작 ▶ 검색명='1mol L Sulfuric acid standard solution 1M 2N 황산 용액' / 순번='6'
# [04:57:23] 138행 ▶ 검색 시작: '1mol L Sulfuric acid standard solution 1M 2N 황산 용액' / 전체 6번째
# [04:57:24]   ✔ 검색어 입력 완료: '1mol L Sulfuric acid standard solution 1M 2N 황산 용액'
# [04:57:24]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:25]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=1mol+L+Sulfuric+acid+standard+solution+1M+2N+%ED%99%A9%EC%82%B0+%EC%9A%A9%EC%95%A1
# [04:57:25]   ▶ 1페이지 아이템 수(page_size)=6
# [04:57:25]   ▶ 목표: page=1, page내순번=6
# [04:57:25]   ▶ 목표 페이지 아이템 수=6
# [04:57:26] 138행 결과 ▶ 가격=11000 / 상태=OK:11000 / CSS / 원문:11,000
# [04:57:26] ================================================================================
# [04:57:26] 139행 시작 ▶ 검색명='Copper II Sulfate Pentahydrate 99 EP' / 순번='1'
# [04:57:26] 139행 ▶ 검색 시작: 'Copper II Sulfate Pentahydrate 99 EP' / 전체 1번째
# [04:57:27]   ✔ 검색어 입력 완료: 'Copper II Sulfate Pentahydrate 99 EP'
# [04:57:27]   ✔ 클릭(JS): 돋보기 (button#sch_submit)
# [04:57:28]   ✔ search.php 이동 확인 / URL: https://www.dslab.co.kr/shop/search.php?q=Copper+II+Sulfate+Pentahydrate+99+EP
# [04:57:28]   ▶ 1페이지 아이템 수(page_size)=9
# [04:57:28]   ▶ 목표: page=1, page내순번=1
# [04:57:28]   ▶ 목표 페이지 아이템 수=9
# [04:57:28] 139행 결과 ▶ 가격=11000 / 상태=OK:11000 / CSS / 원문:11,000
# [04:57:29] 완료 ▶ output.xlsx 저장
